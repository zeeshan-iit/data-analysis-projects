# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ds = pd.read_csv(r"E:\jupyter\loan.csv")

# %%
ds.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP200001    NaN     Yes          0  Not Graduate           Yes
# 1  LP200002   Male     Yes        NaN      Graduate           NaN
# 2  LP200003    NaN      No          2  Not Graduate           Yes
# 3  LP200004    NaN      No        NaN      Graduate            No
# 4  LP200005   Male     NaN          1  Not Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5157                NaN         329             300.0
# 1             4757                NaN         264             360.0
# 2             5027                0.0          97             240.0
# 3             2791                NaN         366             240.0
# 4             5314             3613.0         282             240.0
#
#    Credit_History Property_Area Loan_Status
# 0             0.0         Urban           Y
# 1             1.0         Urban           Y
# 2             1.0         Rural           Y
# 3             NaN     Semiurban           Y
# 4             0.0         Rural           N

# %%
ds.shape
# Out:
# (250, 13)

# %%
(ds.isnull().sum().sum()/(ds.shape[0]*ds.shape[1]))*100
# Out:
# np.float64(18.276923076923076)

# %%
(ds.isnull().sum()/ds.shape[0])*100
# Out:
# Loan_ID               0.0
# Gender               33.2
# Married              35.6
# Dependents           18.8
# Education             0.0
# Self_Employed        38.0
# ApplicantIncome       0.0
# CoapplicantIncome    31.6
# LoanAmount            0.0
# Loan_Amount_Term     15.2
# Credit_History       34.8
# Property_Area        30.4
# Loan_Status           0.0
# dtype: float64

# %%
sns.heatmap(ds.isnull())
plt.show()
